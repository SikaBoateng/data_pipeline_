# %%
import pandas as pd

# %%
mk1_del = pd.read_csv(r"C:\Users\USER\Data-pipeline-Individual\Market 1 Deliveries.csv")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4684\1372414532.py:1: DtypeWarning: Columns (12,14,16,19,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   mk1_del = pd.read_csv(r"C:\Users\USER\Data-pipeline-Individual\Market 1 Deliveries.csv")

# %%
mk1_del.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type
# 0  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery  \
# 1  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 2  303698961   YR-8221753,0  3.040000e+29  Default Team  Delivery
# 3  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
# 4  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
#
#                                       Notes
# 0  Deliver tomorrow morning by 8.00a.m note  \
# 1  Deliver tomorrow morning by 8.00a.m note
# 2               To be delivered today by 12
# 3                              DELIVER BY 6
# 4                              DELIVER BY 6
#
#                                             Agent_ID Agent_Name
# 0  potatoes should be Medium large enough for Mak...    1280904  \
# 1  potatoes should be Medium large enough for Mak...    1280904
# 2                                               30pm    1115711
# 3                                          30 PLEASE          -
# 4                                          30 PLEASE          -
#
#        Distance(m) Total_Time_Taken(min)  ...
# 0  Malombe Kimathi                     -  ...  \
# 1  Malombe Kimathi                     -  ...
# 2    Kennedy Chege                     -  ...
# 3                -                     -  ...
# 4                -                     -  ...
#
#                                         Tip
# 0                                         -  \
# 1  Deliver tomorrow morning by 8.00a.m note
# 2               To be delivered today by 12
# 3                                         -
# 4                              DELIVER BY 6
#
#                                     Delivery_Charges  Discount  Subtotal
# 0                                                  -         -         -  \
# 1  potatoes should be Medium large enough for Mak...  KSh 0.00  KSh 0.00
# 2                                               30pm  KSh 0.00  KSh 0.00
# 3                                                  -         -         -
# 4                                          30 PLEASE  KSh 0.00  KSh 0.00
#
#   Payment_Type  Task_Category Earning Pricing Unnamed: 30 Unnamed: 31
# 0            -              -       -       -           -         NaN
# 1     KSh 0.00           5900    CASH       -           -           -
# 2     KSh 0.00           6080    CASH       -           -           -
# 3            -              -       -       -           -         NaN
# 4     KSh 0.00           5730    CASH       -           -           -
#
# [5 rows x 32 columns]

# %%
mk1_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44983 entries, 0 to 44982
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44983 non-null  int64
#  1   Order_ID               44983 non-null  object
#  2   Relationship           44983 non-null  float64
#  3   Team_Name              44983 non-null  object
#  4   Task_Type              44983 non-null  object
#  5   Notes                  13870 non-null  object
#  6   Agent_ID               44983 non-null  object
#  7   Agent_Name             44983 non-null  object
#  8   Distance(m)            44983 non-null  object
#  9   Total_Time_Taken(min)  44983 non-null  object
#  10  Task_Status            44983 non-null  object
#  11  Ref_Images             44983 non-null  object
#  12  Rating                 44983 non-null  object
#  13  Review                 44966 non-null  object
#  14  Latitude               44983 non-null  object
#  15  Longitude              44983 non-null  float64
#  16  Tags                   110 non-null    object
#  17  Promo_Applied          44874 non-null  object
#  18  Custom_Template_ID     44983 non-null  object
#  19  Task_Details_QTY       44983 non-null  object
#  20  Task_Details_AMOUNT    44983 non-null  object
#  21  Special_Instructions   44982 non-null  object
#  22  Tip                    44983 non-null  object
#  23  Delivery_Charges       44983 non-null  object
#  24  Discount               44983 non-null  object
#  25  Subtotal               44983 non-null  object
#  26  Payment_Type           44983 non-null  object
#  27  Task_Category          44983 non-null  object
#  28  Earning                44983 non-null  object
#  29  Pricing                44983 non-null  object
#  30  Unnamed: 30            109 non-null    object
#  31  Unnamed: 31            39 non-null     object
# dtypes: float64(2), int64(1), object(29)
# memory usage: 11.0+ MB

# %%
mk1_del.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Notes', 'Agent_ID', 'Agent_Name', 'Distance(m)',
#        'Total_Time_Taken(min)', 'Task_Status', 'Ref_Images', 'Rating',
#        'Review', 'Latitude', 'Longitude', 'Tags', 'Promo_Applied',
#        'Custom_Template_ID', 'Task_Details_QTY', 'Task_Details_AMOUNT',
#        'Special_Instructions', 'Tip', 'Delivery_Charges', 'Discount',
#        'Subtotal', 'Payment_Type', 'Task_Category', 'Earning', 'Pricing',
#        'Unnamed: 30', 'Unnamed: 31'],
#       dtype='object')

# %%
col_to_drop = ['Notes',"Tags",'Unnamed: 30', 'Unnamed: 31' ]

# %%
mk1_del = mk1_del.drop(col_to_drop, axis = 1)

# %%
mk1_del.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type
# 0  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery  \
# 1  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 2  303698961   YR-8221753,0  3.040000e+29  Default Team  Delivery
# 3  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
# 4  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
#
#                                             Agent_ID Agent_Name
# 0  potatoes should be Medium large enough for Mak...    1280904  \
# 1  potatoes should be Medium large enough for Mak...    1280904
# 2                                               30pm    1115711
# 3                                          30 PLEASE          -
# 4                                          30 PLEASE          -
#
#        Distance(m) Total_Time_Taken(min)           Task_Status  ...
# 0  Malombe Kimathi                     -  18 Jan 2022 07:59:25  ...  \
# 1  Malombe Kimathi                     -  18 Jan 2022 07:59:25  ...
# 2    Kennedy Chege                     -  31 Aug 2021 17:06:28  ...
# 3                -                     -  26 Aug 2021 21:42:40  ...
# 4                -                     -  26 Aug 2021 21:42:40  ...
#
#   Task_Details_AMOUNT Special_Instructions
# 0                   2          KSh 5500.00  \
# 1                   2           KSh 400.00
# 2                   4          KSh 6080.00
# 3                   3          KSh 4560.00
# 4                   1          KSh 1170.00
#
#                                         Tip
# 0                                         -  \
# 1  Deliver tomorrow morning by 8.00a.m note
# 2               To be delivered today by 12
# 3                                         -
# 4                              DELIVER BY 6
#
#                                     Delivery_Charges  Discount  Subtotal
# 0                                                  -         -         -  \
# 1  potatoes should be Medium large enough for Mak...  KSh 0.00  KSh 0.00
# 2                                               30pm  KSh 0.00  KSh 0.00
# 3                                                  -         -         -
# 4                                          30 PLEASE  KSh 0.00  KSh 0.00
#
#   Payment_Type Task_Category Earning Pricing
# 0            -             -       -       -
# 1     KSh 0.00          5900    CASH       -
# 2     KSh 0.00          6080    CASH       -
# 3            -             -       -       -
# 4     KSh 0.00          5730    CASH       -
#
# [5 rows x 28 columns]

# %%
mk1_del.isnull().sum()
# Out:
# Task_ID                    0
# Order_ID                   0
# Relationship               0
# Team_Name                  0
# Task_Type                  0
# Agent_ID                   0
# Agent_Name                 0
# Distance(m)                0
# Total_Time_Taken(min)      0
# Task_Status                0
# Ref_Images                 0
# Rating                     0
# Review                    17
# Latitude                   0
# Longitude                  0
# Promo_Applied            109
# Custom_Template_ID         0
# Task_Details_QTY           0
# Task_Details_AMOUNT        0
# Special_Instructions       1
# Tip                        0
# Delivery_Charges           0
# Discount                   0
# Subtotal                   0
# Payment_Type               0
# Task_Category              0
# Earning                    0
# Pricing                    0
# dtype: int64

# %%
mk1_del = mk1_del.dropna()

# %%
mk1_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44856 entries, 109 to 44982
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44856 non-null  int64
#  1   Order_ID               44856 non-null  object
#  2   Relationship           44856 non-null  float64
#  3   Team_Name              44856 non-null  object
#  4   Task_Type              44856 non-null  object
#  5   Agent_ID               44856 non-null  object
#  6   Agent_Name             44856 non-null  object
#  7   Distance(m)            44856 non-null  object
#  8   Total_Time_Taken(min)  44856 non-null  object
#  9   Task_Status            44856 non-null  object
#  10  Ref_Images             44856 non-null  object
#  11  Rating                 44856 non-null  object
#  12  Review                 44856 non-null  object
#  13  Latitude               44856 non-null  object
#  14  Longitude              44856 non-null  float64
#  15  Promo_Applied          44856 non-null  object
#  16  Custom_Template_ID     44856 non-null  object
#  17  Task_Details_QTY       44856 non-null  object
#  18  Task_Details_AMOUNT    44856 non-null  object
#  19  Special_Instructions   44856 non-null  object
#  20  Tip                    44856 non-null  object
#  21  Delivery_Charges       44856 non-null  object
#  22  Discount               44856 non-null  object
#  23  Subtotal               44856 non-null  object
#  24  Payment_Type           44856 non-null  object
#  25  Task_Category          44856 non-null  object
#  26  Earning                44856 non-null  object
#  27  Pricing                44856 non-null  object
# dtypes: float64(2), int64(1), object(25)
# memory usage: 9.9+ MB

# %%
mk1_del.to_csv('up_mk1_del.csv', index=False)

# %%
df1 = pd.read_csv('up_mk1_del.csv')
df2 = pd.read_csv('up_mk1_cus.csv')
df6 = pd.read_csv('up_mk1_orders.csv', usecols = ['Order ID', 'Customer ID'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4684\3203423425.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('up_mk1_del.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44856 entries, 0 to 44855
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44856 non-null  int64
#  1   Order_ID               44856 non-null  object
#  2   Relationship           44856 non-null  float64
#  3   Team_Name              44856 non-null  object
#  4   Task_Type              44856 non-null  object
#  5   Agent_ID               44856 non-null  object
#  6   Agent_Name             44856 non-null  object
#  7   Distance(m)            44856 non-null  object
#  8   Total_Time_Taken(min)  44856 non-null  object
#  9   Task_Status            44856 non-null  object
#  10  Ref_Images             44856 non-null  object
#  11  Rating                 44856 non-null  int64
#  12  Review                 44856 non-null  object
#  13  Latitude               44856 non-null  float64
#  14  Longitude              44856 non-null  float64
#  15  Promo_Applied          44856 non-null  object
#  16  Custom_Template_ID     44856 non-null  object
#  17  Task_Details_QTY       44856 non-null  object
#  18  Task_Details_AMOUNT    44856 non-null  object
#  19  Special_Instructions   44856 non-null  object
#  20  Tip                    44856 non-null  object
#  21  Delivery_Charges       44856 non-null  object
#  22  Discount               44856 non-null  object
#  23  Subtotal               44856 non-null  object
#  24  Payment_Type           44856 non-null  object
#  25  Task_Category          44856 non-null  object
#  26  Earning                44856 non-null  object
#  27  Pricing                44856 non-null  object
# dtypes: float64(3), int64(2), object(23)
# memory usage: 9.6+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         4177 non-null   int64
#  1   Last Used Platform  4177 non-null   object
#  2   Is Blocked          4177 non-null   int64
#  3   Created At          4177 non-null   object
#  4   Language            4177 non-null   object
#  5   Outstanding Amount  4177 non-null   int64
#  6   Loyalty Points      4177 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 228.6+ KB

# %% [markdown]
# after performing set method on the columns , columns i can drop are Team_Name with value "Default Team" and Pricing with values "-" or "0"

# %%
merged_ord1_cus1 = pd.merge(df6, df2, on='Customer ID', how='left')

# %%
merged_ord1_cus1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12233 entries, 0 to 12232
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            12233 non-null  int64
#  1   Customer ID         12233 non-null  int64
#  2   Last Used Platform  12233 non-null  object
#  3   Is Blocked          12233 non-null  int64
#  4   Created At          12233 non-null  object
#  5   Language            12233 non-null  object
#  6   Outstanding Amount  12233 non-null  int64
#  7   Loyalty Points      12233 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 764.7+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44856 entries, 0 to 44855
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44856 non-null  int64
#  1   Order_ID               44856 non-null  object
#  2   Relationship           44856 non-null  float64
#  3   Team_Name              44856 non-null  object
#  4   Task_Type              44856 non-null  object
#  5   Agent_ID               44856 non-null  object
#  6   Agent_Name             44856 non-null  object
#  7   Distance(m)            44856 non-null  object
#  8   Total_Time_Taken(min)  44856 non-null  object
#  9   Task_Status            44856 non-null  object
#  10  Ref_Images             44856 non-null  object
#  11  Rating                 44856 non-null  int64
#  12  Review                 44856 non-null  object
#  13  Latitude               44856 non-null  float64
#  14  Longitude              44856 non-null  float64
#  15  Promo_Applied          44856 non-null  object
#  16  Custom_Template_ID     44856 non-null  object
#  17  Task_Details_QTY       44856 non-null  object
#  18  Task_Details_AMOUNT    44856 non-null  object
#  19  Special_Instructions   44856 non-null  object
#  20  Tip                    44856 non-null  object
#  21  Delivery_Charges       44856 non-null  object
#  22  Discount               44856 non-null  object
#  23  Subtotal               44856 non-null  object
#  24  Payment_Type           44856 non-null  object
#  25  Task_Category          44856 non-null  object
#  26  Earning                44856 non-null  object
#  27  Pricing                44856 non-null  object
# dtypes: float64(3), int64(2), object(23)
# memory usage: 9.6+ MB

# %%
df1.rename(columns = {'Order_ID': 'Order ID'}, inplace = True)

# %%
# Convert 'Order ID' column to string type in merged_ord1_cus1 DataFrame
merged_ord1_cus1['Order ID'] = merged_ord1_cus1['Order ID'].astype(str)

# %%
merged_del1_cus1 = pd.merge(df1, merged_ord1_cus1, on='Order ID', how='inner')

# %%
merged_del1_cus1.head()
# Out:
# Empty DataFrame
# Columns: [Task_ID, Order ID, Relationship, Team_Name, Task_Type, Agent_ID, Agent_Name, Distance(m), Total_Time_Taken(min), Task_Status, Ref_Images, Rating, Review, Latitude, Longitude, Promo_Applied, Custom_Template_ID, Task_Details_QTY, Task_Details_AMOUNT, Special_Instructions, Tip, Delivery_Charges, Discount, Subtotal, Payment_Type, Task_Category, Earning, Pricing, Customer ID, Last Used Platform, Is Blocked, Created At, Language, Outstanding Amount, Loyalty Points]
# Index: []
#
# [0 rows x 35 columns]

# %%
merged_del1_cus1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44856 entries, 0 to 44855
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44856 non-null  int64
#  1   Order ID               44856 non-null  object
#  2   Relationship           44856 non-null  float64
#  3   Team_Name              44856 non-null  object
#  4   Task_Type              44856 non-null  object
#  5   Agent_ID               44856 non-null  object
#  6   Agent_Name             44856 non-null  object
#  7   Distance(m)            44856 non-null  object
#  8   Total_Time_Taken(min)  44856 non-null  object
#  9   Task_Status            44856 non-null  object
#  10  Ref_Images             44856 non-null  object
#  11  Rating                 44856 non-null  int64
#  12  Review                 44856 non-null  object
#  13  Latitude               44856 non-null  float64
#  14  Longitude              44856 non-null  float64
#  15  Promo_Applied          44856 non-null  object
#  16  Custom_Template_ID     44856 non-null  object
#  17  Task_Details_QTY       44856 non-null  object
#  18  Task_Details_AMOUNT    44856 non-null  object
#  19  Special_Instructions   44856 non-null  object
#  20  Tip                    44856 non-null  object
#  21  Delivery_Charges       44856 non-null  object
#  22  Discount               44856 non-null  object
#  23  Subtotal               44856 non-null  object
#  24  Payment_Type           44856 non-null  object
#  25  Task_Category          44856 non-null  object
#  26  Earning                44856 non-null  object
#  27  Pricing                44856 non-null  object
#  28  Customer ID            0 non-null      float64
#  29  Last Used Platform     0 non-null      object
#  30  Is Blocked             0 non-null      float64
#  31  Created At             0 non-null      object
#  32  Language               0 non-null      object
#  33  Outstanding Amount     0 non-null      float64
#  34  Loyalty Points         0 non-null      float64
# dtypes: float64(7), int64(2), object(26)
# memory usage: 12.0+ MB

# %%
set(merged_del1_cus1['Customer ID'])
# Out:
0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4463922.0,
#  nan,
#  nan,
#  nan,
#  4595000.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4201798.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4595045.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4070784.0,
#  nan,
#  nan,
#  4201860.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4070821.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4464051.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4202004.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4070946.0,
#  nan,
#  nan,
#  nan,
#  4070952.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  4095456.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4070988.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4071050.0,
#  nan,
#  nan,
#  nan,
#  4333200.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4333213.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4071116.0,
#  nan,
#  nan,
#  4464335.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  4464344.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4464368.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4464408.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4333356.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4482462.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4333460.0,
#  nan,
#  4726678.0,
#  nan,
#  nan,
#  4333465.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4071371.0,
#  nan,
#  4333517.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  5159833.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  3700956.0,
#  4225729.0,
#  3700969.0,
#  4333678.0,
#  4482522.0,
#  4202658.0,
#  4071602.0,
#  4612794.0,
#  3547388.0,
#  4482557.0,
#  4873333.0,
#  4877004.0,
#  4071751.0,
#  4333943.0,
#  3701035.0,
#  4202926.0,
#  4465072.0,
#  4202948.0,
#  5120508.0,
#  3547736.0,
#  4095499.0,
#  3831333.0,
#  3444996.0,
#  3831343.0,
#  4596396.0,
#  3701093.0,
#  4596442.0,
#  4334310.0,
#  5159988.0,
#  4596465.0,
#  4334347.0,
#  4465442.0,
#  4596626.0,
#  4334555.0,
#  4096443.0,
#  3679215.0,
#  4334581.0,
#  3417088.0,
#  4482704.0,
#  4596806.0,
#  4096264.0,
#  3417198.0,
#  3701183.0,
#  4222219.0,
#  4334864.0,
#  4482757.0,
#  4334876.0,
#  4334889.0,
#  4334904.0,
#  3941846.0,
#  3941860.0,
#  3417637.0,
#  3941970.0,
#  4204169.0,
#  4466332.0,
#  4335274.0,
#  4482842.0,
#  3942129.0,
#  4466444.0,
#  3942160.0,
#  4466463.0,
#  4466483.0,
#  3942218.0,
#  3942287.0,
#  4466608.0,
#  3942343.0,
#  4335574.0,
#  4095555.0,
#  3942398.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4222396.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4092145.0,
#  nan,
#  nan,
#  nan,
#  4466755.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  3549348.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4466868.0,
#  nan,
#  nan,
#  3942584.0,
#  nan,
#  4335800.0,
#  nan,
#  4335804.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4335825.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  3942619.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4466943.0,
#  nan,
#  nan,
#  nan,
#  3418374.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  5122347.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  3811665.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...}

# %%
merged_del1_cus1.columns
# Out:
# Index(['Task_ID', 'Order ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Agent_ID', 'Agent_Name', 'Distance(m)', 'Total_Time_Taken(min)',
#        'Task_Status', 'Ref_Images', 'Rating', 'Review', 'Latitude',
#        'Longitude', 'Promo_Applied', 'Custom_Template_ID', 'Task_Details_QTY',
#        'Task_Details_AMOUNT', 'Special_Instructions', 'Tip',
#        'Delivery_Charges', 'Discount', 'Subtotal', 'Payment_Type',
#        'Task_Category', 'Earning', 'Pricing', 'Customer ID',
#        'Last Used Platform', 'Is Blocked', 'Created At', 'Language',
#        'Outstanding Amount', 'Loyalty Points'],
#       dtype='object')
