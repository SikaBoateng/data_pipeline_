# %%
import pandas as pd

# %%
mk2_del = pd.read_csv(r"C:\Users\USER\Data-pipeline-Individual\Market 2 Deliveries.csv")

# %%
mk2_del.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type Notes
# 0  368032956  YR-11262518,0  3.680000e+29  Default Team  Delivery   NaN  \
# 1  368032956  YR-11262518,0  3.680000e+29  Default Team  Delivery   NaN
# 2  368012178  YR-11261796,0  3.680000e+29  Default Team  Delivery   NaN
# 3  368012178  YR-11261796,0  3.680000e+29  Default Team  Delivery   NaN
# 4  367999205  YR-11261341,0  3.680000e+29  Default Team  Delivery   NaN
#
#   Agent_ID Distance(m) Total_Time_Taken(min) Task_Status  ...
# 0  1150142           -                     -    Assigned  ...  \
# 1  1150142           -                     -    Assigned  ...
# 2  1166840          11                     -  In Transit  ...
# 3  1166840          11                     -  In Transit  ...
# 4  1233220           -                     -    Assigned  ...
#
#   Task_Details_AMOUNT  Special_Instructions     Tip  Delivery_Charges
# 0         ₦ 104250.00                     -       -                 -  \
# ...

# %%
mk2_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8019 entries, 0 to 8018
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                8019 non-null   int64
#  1   Order_ID               8019 non-null   object
#  2   Relationship           8019 non-null   float64
#  3   Team_Name              8019 non-null   object
#  4   Task_Type              8019 non-null   object
#  5   Notes                  6 non-null      object
#  6   Agent_ID               8019 non-null   object
#  7   Distance(m)            8019 non-null   object
#  8   Total_Time_Taken(min)  8019 non-null   object
#  9   Task_Status            8019 non-null   object
#  10  Ref_Images             8019 non-null   object
#  11  Rating                 8019 non-null   int64
#  12  Review                 8011 non-null   object
#  13  Latitude               8019 non-null   float64
# ...

# %%
mk2_del.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Notes', 'Agent_ID', 'Distance(m)', 'Total_Time_Taken(min)',
#        'Task_Status', 'Ref_Images', 'Rating', 'Review', 'Latitude',
#        'Longitude', 'Tags', 'Promo_Applied', 'Custom_Template_ID',
#        'Task_Details_QTY', 'Task_Details_AMOUNT', 'Special_Instructions',
#        'Tip', 'Delivery_Charges', 'Discount', 'Subtotal', 'Payment_Type',
#        'Task_Category', 'Earning', 'Pricing'],
#       dtype='object')

# %%
coll_to_drop = ['Notes',"Tags"]

# %%
mk2_del = mk2_del.drop(coll_to_drop, axis = 1)

# %%
mk2_del.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type Agent_ID
# 0  368032956  YR-11262518,0  3.680000e+29  Default Team  Delivery  1150142  \
# 1  368032956  YR-11262518,0  3.680000e+29  Default Team  Delivery  1150142
# 2  368012178  YR-11261796,0  3.680000e+29  Default Team  Delivery  1166840
# 3  368012178  YR-11261796,0  3.680000e+29  Default Team  Delivery  1166840
# 4  367999205  YR-11261341,0  3.680000e+29  Default Team  Delivery  1233220
#
#   Distance(m) Total_Time_Taken(min) Task_Status Ref_Images  ...
# 0           -                     -    Assigned          -  ...  \
# 1           -                     -    Assigned          -  ...
# 2          11                     -  In Transit          -  ...
# 3          11                     -  In Transit          -  ...
# 4           -                     -    Assigned          -  ...
#
#    Task_Details_AMOUNT Special_Instructions     Tip  Delivery_Charges
# ...

# %%
mk2_del.isnull().sum()
# Out:
# Task_ID                  0
# Order_ID                 0
# Relationship             0
# Team_Name                0
# Task_Type                0
# Agent_ID                 0
# Distance(m)              0
# Total_Time_Taken(min)    0
# Task_Status              0
# Ref_Images               0
# Rating                   0
# Review                   8
# Latitude                 0
# Longitude                0
# Promo_Applied            0
# Custom_Template_ID       0
# Task_Details_QTY         0
# Task_Details_AMOUNT      0
# Special_Instructions     1
# Tip                      0
# Delivery_Charges         0
# Discount                 0
# Subtotal                 0
# Payment_Type             0
# Task_Category            0
# Earning                  0
# Pricing                  0
# dtype: int64

# %%
mk2_del = mk2_del.dropna()

# %%
mk2_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8010 entries, 0 to 8018
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                8010 non-null   int64
#  1   Order_ID               8010 non-null   object
#  2   Relationship           8010 non-null   float64
#  3   Team_Name              8010 non-null   object
#  4   Task_Type              8010 non-null   object
#  5   Agent_ID               8010 non-null   object
#  6   Distance(m)            8010 non-null   object
#  7   Total_Time_Taken(min)  8010 non-null   object
#  8   Task_Status            8010 non-null   object
#  9   Ref_Images             8010 non-null   object
#  10  Rating                 8010 non-null   int64
#  11  Review                 8010 non-null   object
#  12  Latitude               8010 non-null   float64
#  13  Longitude              8010 non-null   float64
# ...

# %% [markdown]
# set(df_name[column_name])

# %%
mk2_del.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Agent_ID', 'Distance(m)', 'Total_Time_Taken(min)', 'Task_Status',
#        'Ref_Images', 'Rating', 'Review', 'Latitude', 'Longitude',
#        'Promo_Applied', 'Custom_Template_ID', 'Task_Details_QTY',
#        'Task_Details_AMOUNT', 'Special_Instructions', 'Tip',
#        'Delivery_Charges', 'Discount', 'Subtotal', 'Payment_Type',
#        'Task_Category', 'Earning', 'Pricing'],
#       dtype='object')

# %%
mk2_del.to_csv('up_mk2_del.csv', index=False)

# %%
mk2_del.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Agent_ID', 'Distance(m)', 'Total_Time_Taken(min)', 'Task_Status',
#        'Ref_Images', 'Rating', 'Review', 'Latitude', 'Longitude',
#        'Promo_Applied', 'Custom_Template_ID', 'Task_Details_QTY',
#        'Task_Details_AMOUNT', 'Special_Instructions', 'Tip',
#        'Delivery_Charges', 'Discount', 'Subtotal', 'Payment_Type',
#        'Task_Category', 'Earning', 'Pricing'],
#       dtype='object')

# %% [markdown]
# after performing set method on the columns , columns i can drop are Team_Name with value "Default Team",  Pricing with values "-" or "0", Earning with value "-" and Task_Category with value "-"
